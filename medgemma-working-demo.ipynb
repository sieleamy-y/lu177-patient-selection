# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/google/medgemma-1.5-4b-it
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/google/medgemma-1.5-4b-it)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Install required packages
# !pip install -q transformers accelerate

# Login to Hugging Face using Kaggle secrets
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    hf_token = user_secrets.get_secret("HF_TOKEN")
    print("✅ Retrieved HF_TOKEN from Kaggle secrets")
except:
    print("❌ Could not get HF_TOKEN - check Secrets panel")
    raise

from huggingface_hub import login
login(token=hf_token)

print("✅ Logged in to Hugging Face!")

# Load MedGemma for TEXT-ONLY clinical reasoning
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

print("Loading MedGemma 1.5 4B...")

model_id = "google/medgemma-1.5-4b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=hf_token)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    token=hf_token,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("✅ MedGemma loaded successfully!")# Install required packages
# !pip install -q transformers accelerate

# Login to Hugging Face using Kaggle secrets
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    hf_token = user_secrets.get_secret("HF_TOKEN")
    print("✅ Retrieved HF_TOKEN from Kaggle secrets")
except:
    print("❌ Could not get HF_TOKEN - check Secrets panel")
    raise

from huggingface_hub import login
login(token=hf_token)

print("✅ Logged in to Hugging Face!")

# Load MedGemma for TEXT-ONLY clinical reasoning
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

print("Loading MedGemma 1.5 4B...")

model_id = "google/medgemma-1.5-4b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=hf_token)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    token=hf_token,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("✅ MedGemma loaded successfully!")# Install required packages
# !pip install -q transformers accelerate

# Login to Hugging Face using Kaggle secrets
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    hf_token = user_secrets.get_secret("HF_TOKEN")
    print("✅ Retrieved HF_TOKEN from Kaggle secrets")
except:
    print("❌ Could not get HF_TOKEN - check Secrets panel")
    raise

from huggingface_hub import login
login(token=hf_token)

print("✅ Logged in to Hugging Face!")

# Load MedGemma for TEXT-ONLY clinical reasoning
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

print("Loading MedGemma 1.5 4B...")

model_id = "google/medgemma-1.5-4b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=hf_token)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    token=hf_token,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("✅ MedGemma loaded successfully!")# Install required packages
# !pip install -q transformers accelerate

# Login to Hugging Face using Kaggle secrets
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    hf_token = user_secrets.get_secret("HF_TOKEN")
    print("✅ Retrieved HF_TOKEN from Kaggle secrets")
except:
    print("❌ Could not get HF_TOKEN - check Secrets panel")
    raise

from huggingface_hub import login
login(token=hf_token)

print("✅ Logged in to Hugging Face!")

# Load MedGemma for TEXT-ONLY clinical reasoning
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

print("Loading MedGemma 1.5 4B...")

model_id = "google/medgemma-1.5-4b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=hf_token)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    token=hf_token,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("✅ MedGemma loaded successfully!")# Install required packages
# !pip install -q transformers accelerate

# Login to Hugging Face using Kaggle secrets
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

try:
    hf_token = user_secrets.get_secret("HF_TOKEN")
    print("✅ Retrieved HF_TOKEN from Kaggle secrets")
except:
    print("❌ Could not get HF_TOKEN - check Secrets panel")
    raise

from huggingface_hub import login
login(token=hf_token)

print("✅ Logged in to Hugging Face!")

# Load MedGemma for TEXT-ONLY clinical reasoning
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

print("Loading MedGemma 1.5 4B...")

model_id = "google/medgemma-1.5-4b-it"

tokenizer = AutoTokenizer.from_pretrained(model_id, token=hf_token)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    token=hf_token,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("✅ MedGemma loaded successfully!")
# Out:
# ✅ Retrieved HF_TOKEN from Kaggle secrets
# ✅ Logged in to Hugging Face!
# Loading MedGemma 1.5 4B...
# config.json:   0%|          | 0.00/2.55k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# ✅ MedGemma loaded successfully!
# ✅ Retrieved HF_TOKEN from Kaggle secrets
# ✅ Logged in to Hugging Face!
# Loading MedGemma 1.5 4B...
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# ✅ MedGemma loaded successfully!
# ✅ Retrieved HF_TOKEN from Kaggle secrets
# ✅ Logged in to Hugging Face!
# Loading MedGemma 1.5 4B...
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# ✅ MedGemma loaded successfully!
# ✅ Retrieved HF_TOKEN from Kaggle secrets
# ✅ Logged in to Hugging Face!
# Loading MedGemma 1.5 4B...
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# ✅ MedGemma loaded successfully!
# ✅ Retrieved HF_TOKEN from Kaggle secrets
# ✅ Logged in to Hugging Face!
# Loading MedGemma 1.5 4B...
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# ✅ MedGemma loaded successfully!

# %%
# Clear GPU memory
import torch
torch.cuda.empty_cache()
import gc
gc.collect()
# Test with clinical reasoning prompt
prompt = """You are a nuclear medicine physician expert in Lu-177 PSMA radioligand therapy.

PATIENT DATA:
- Kidney absorbed dose (Ga-68 scan): 12.5 Gy
- Predicted Lu-177 kidney dose: 18.3 Gy
- eGFR: 45 mL/min/1.73m²
- Prior kidney disease: Stage 3a CKD

QUESTION: Is this patient eligible for Lu-177 PSMA therapy according to EANM guidelines?

Provide structured response:
1. Eligibility (Yes/No/With modifications)
2. Key considerations
3. Dose recommendations
4. Monitoring requirements"""

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

print("\n" + "="*70)
print("GENERATING MEDGEMMA CLINICAL RECOMMENDATION...")
print("="*70)

outputs = model.generate(
    **inputs,
    max_new_tokens=500,
    temperature=0.7,
    do_sample=True
)

response = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("\n" + "="*70)
print("MEDGEMMA RESPONSE:")
print("="*70)
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# ======================================================================
# GENERATING MEDGEMMA CLINICAL RECOMMENDATION...
# ======================================================================
#
# ======================================================================
# MEDGEMMA RESPONSE:
# ======================================================================
# You are a nuclear medicine physician expert in Lu-177 PSMA radioligand therapy.
#
# PATIENT DATA:
# - Kidney absorbed dose (Ga-68 scan): 12.5 Gy
# - Predicted Lu-177 kidney dose: 18.3 Gy
# - eGFR: 45 mL/min/1.73m²
# - Prior kidney disease: Stage 3a CKD
#
# QUESTION: Is this patient eligible for Lu-177 PSMA therapy according to EANM guidelines?
#
# Provide structured response:
# 1. Eligibility (Yes/No/With modifications)
# 2. Key considerations
# 3. Dose recommendations
# 4. Monitoring requirements
# 5. Contraindications/Precautions
#
# Let's break down the considerations for each section:
#
# 1.  **Eligibility:**
#     *   **Core Criteria:** The patient has a documented prostate cancer diagnosis and is being considered for Lu-177 PSMA therapy. This is the fundamental requirement.
#     *   **Kidney Function:** The patient has a CKD stage 3a (eGFR 45 mL/min/1.73m²). This is a critical factor.
#     *   **Comparison:** Compare the predicted Lu-177 kidney dose (18.3 Gy) to the EANM guideline threshold for kidney dose in patients with CKD. The threshold is generally considered to be 15 Gy for CKD stage 3 and higher.
#     *   **Conclusion:** Since the predicted Lu-177 kidney dose (18.3 Gy) exceeds the EANM guideline threshold (15 Gy) for patients with CKD stage 3a, the patient is **not** eligible for standard Lu-177 PSMA therapy.
#
# 2.  **Key Considerations:**
#     *   **Kidney Dose:** The primary concern is the predicted Lu-177 kidney dose. The EANM guidelines explicitly state that Lu-177 PSMA therapy should not be administered to patients with CKD stage 3a or worse (eGFR < 60 mL/min/1.73m²) due to the significantly increased risk of acute kidney injury (AKI).
#     *   **Patient's CKD Stage:** The patient's eGFR of 45 mL/min/1.73m² falls into CKD stage 3a, which is precisely the category excluded by the guidelines.
#     *   **Risk vs. Benefit:** While the risk of AKI is high, the potential benefit of Lu-177 PSMA therapy for prostate cancer in this specific patient might be considered, *but only* after extensive discussion with the patient regarding the risks and potential benefits, and potentially after consultation with a nephrologist. The EANM guidelines emphasize this limitation.
#     *   **Alternative Therapies:** Consider alternative therapeutic options for this patient, such as external beam radiotherapy (EBRT), androgen deprivation therapy (ADT), or potentially other radioligand therapies (e.g., Ga-68 PSMA

# %%
import torch

print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0))
print("Total GPU Memory:", torch.cuda.get_device_properties(0).total_memory / 1e9, "GB")
print("Allocated:", torch.cuda.memory_allocated(0) / 1e9, "GB")
print("Reserved:", torch.cuda.memory_reserved(0) / 1e9, "GB")
print("Free:", (torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_allocated(0)) / 1e9, "GB")
# Out:
# GPU Available: True
# GPU Name: Tesla T4
# Total GPU Memory: 15.637086208 GB
# Allocated: 8.608854016 GB
# Reserved: 15.449718784 GB
# Free: 7.028232192 GB

# %%
# Clear GPU memory before next case
torch.cuda.empty_cache()
gc.collect()

print("\n" + "="*70)
print("CASE 3: HIGH RISK")
print("="*70)

prompt_case3 = """You are a nuclear medicine physician expert in Lu-177 PSMA radioligand therapy.

PATIENT DATA:
- Kidney absorbed dose (Ga-68 scan): 20.0 Gy
- Predicted Lu-177 kidney dose: 29.4 Gy
- eGFR: 35 mL/min/1.73m²
- Prior kidney disease: Stage 3b CKD

QUESTION: Is this patient eligible for Lu-177 PSMA therapy according to EANM guidelines?

Provide structured response:
1. Eligibility (Yes/No/With modifications)
2. Key considerations
3. Dose recommendations
4. Monitoring requirements"""

inputs = tokenizer(prompt_case3, return_tensors="pt").to(model.device)

outputs = model.generate(
    **inputs,
    max_new_tokens=500,
    temperature=0.7,
    do_sample=True
)

response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
# Out:
# Setting `pad_token_id` to `eos_token_id`:1 for open-end generation.
# ======================================================================
# CASE 3: HIGH RISK
# ======================================================================
# You are a nuclear medicine physician expert in Lu-177 PSMA radioligand therapy.
#
# PATIENT DATA:
# - Kidney absorbed dose (Ga-68 scan): 20.0 Gy
# - Predicted Lu-177 kidney dose: 29.4 Gy
# - eGFR: 35 mL/min/1.73m²
# - Prior kidney disease: Stage 3b CKD
#
# QUESTION: Is this patient eligible for Lu-177 PSMA therapy according to EANM guidelines?
#
# Provide structured response:
# 1. Eligibility (Yes/No/With modifications)
# 2. Key considerations
# 3. Dose recommendations
# 4. Monitoring requirements
#
# ---
#
# **1. Eligibility:**
#
# No, this patient is **not** eligible for Lu-177 PSMA therapy according to EANM guidelines.
#
# **Reasoning:**
#
# *   **Kidney Function:** The patient's estimated Glomerular Filtration Rate (eGFR) is 35 mL/min/1.73m².
# *   **EANM Guideline Threshold:** The EANM guidelines state that Lu-177 PSMA therapy is contraindicated in patients with a predicted Lu-177 kidney dose (Ki-PSMA) exceeding 20 Gy.
# *   **Calculated Dose:** The predicted Lu-177 kidney dose is 29.4 Gy, which is above the guideline threshold of 20 Gy.
# *   **Prior Kidney Disease:** The patient already has pre-existing Stage 3b Chronic Kidney Disease (CKD), which further increases the risk associated with radiation exposure to the kidneys.
#
# **2. Key Considerations:**
#
# *   **High Risk:** The patient has both impaired kidney function (eGFR 35) and a predicted high radiation dose (29.4 Gy) to the kidneys. This combination places them in a high-risk category for severe acute kidney injury (AKI) and long-term kidney damage following Lu-177 PSMA therapy.
# *   **Risk Mitigation (If considered despite guidelines):** While the guidelines are clear, in cases of extreme clinical urgency where the benefits are deemed substantial and risks are meticulously discussed (often outside standard protocol), modifications *might* be considered, but this is **not** standard practice and carries significant risks. In this specific scenario, the risk likely outweighs any potential benefit.
# *   **Alternative Treatment:** Given the contraindication, alternative treatment options for metastatic castration-sensitive prostate cancer (mCSPC) should be strongly considered.
#
# **3. Dose Recommendations:**
#
# *   **Contraindicated:** Lu-177 PSMA therapy is contraindicated in this patient due to the predicted Ki-PSMA exceeding 20 Gy.
#
# **4. Monitoring Requirements:**
#
# *   **Pre-treatment:** Thorough assessment of renal function (eGFR, creatinine, BUN, urinalysis, possibly renal ultrasound) is mandatory.
# *   **During Treatment:** Close monitoring of renal function (eGFR, creatinine) is required before, during, and after the administration of Lu-1
